# %%
from sklearn.metrics import precision_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score
from sklearn.metrics import classification_report
import pandas as pd
from scipy import stats
from pydataset import data
import numpy as np
import env
import matplotlib.pyplot as plt
import os
import prepare
import acquire
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.ensemble import RandomForestClassifier
import warnings
warnings.filterwarnings('ignore')
from sklearn.neighbors import KNeighborsClassifier

# %%
telco_df = acquire.get_telco_data()
telco_df.head()
# Out:
#    Unnamed: 0 customer_id  payment_type_id  internet_service_type_id  \
# 0           0  0002-ORFBO                2                         1
# 1           1  0003-MKNFE                2                         1
# 2           2  0004-TLHLJ                1                         2
# 3           3  0011-IGKFF                1                         2
# 4           4  0013-EXCHZ                2                         2
#
#    contract_type_id  gender  senior_citizen partner dependents  tenure  ...  \
# 0                 2  Female               0     Yes        Yes       9  ...
# 1                 1    Male               0      No         No       9  ...
# 2                 1    Male               0      No         No       4  ...
# 3                 1    Male               1     Yes         No      13  ...
# 4                 1  Female               1     Yes         No       3  ...
#
#            signup_date phone_service.1 multiple_lines.1  \
# 0  2021-04-21 18:07:34             Yes               No
# 1  2021-04-21 18:07:34             Yes              Yes
# 2  2021-09-21 18:07:34             Yes               No
# 3  2020-12-21 18:07:34             Yes               No
# 4  2021-10-21 18:07:34             Yes               No
#
#   internet_service_type_id.1 online_security.1 online_backup.1  \
# 0                          1                No             Yes
# 1                          1                No              No
# 2                          2                No              No
# 3                          2                No             Yes
# 4                          2                No              No
#
#   device_protection.1 tech_support.1 streaming_tv.1  streaming_movies.1
# 0                  No            Yes            Yes                  No
# 1                  No             No             No                 Yes
# 2                 Yes             No             No                  No
# 3                 Yes             No            Yes                 Yes
# 4                  No            Yes            Yes                  No
#
# [5 rows x 44 columns]

# %%
telco_clean_df = prepare.clean_telco(telco_df)
telco_clean_df.head()
# Out:
#    gender  senior_citizen partner dependents  tenure phone_service  \
# 0  Female               0     Yes        Yes       9           Yes
# 1    Male               0      No         No       9           Yes
# 2    Male               0      No         No       4           Yes
# 3    Male               1     Yes         No      13           Yes
# 4  Female               1     Yes         No       3           Yes
#
#   multiple_lines online_security online_backup device_protection  ...  \
# 0             No              No           Yes                No  ...
# 1            Yes              No            No                No  ...
# 2             No              No            No               Yes  ...
# 3             No              No           Yes               Yes  ...
# 4             No              No            No                No  ...
#
#   streaming_tv streaming_movies paperless_billing monthly_charges  churn  \
# 0          Yes               No               Yes            65.6     No
# 1           No              Yes                No            59.9     No
# 2           No               No               Yes            73.9    Yes
# 3          Yes              Yes               Yes            98.0    Yes
# 4          Yes               No               Yes            83.9    Yes
#
#     contract_type internet_service_type      payment_type  \
# 0        One year                   DSL      Mailed check
# 1  Month-to-month                   DSL      Mailed check
# 2  Month-to-month           Fiber optic  Electronic check
# 3  Month-to-month           Fiber optic  Electronic check
# 4  Month-to-month           Fiber optic      Mailed check
#
#            signup_date total_charges
# 0  2021-04-21 18:07:34         590.4
# 1  2021-04-21 18:07:34         539.1
# 2  2021-09-21 18:07:34         295.6
# 3  2020-12-21 18:07:34        1274.0
# 4  2021-10-21 18:07:34         251.7
#
# [5 rows x 21 columns]

# %%
telco_clean_df['charge_rank'] = pd.qcut(telco_clean_df['total_charges'], 4, labels = ['a','b','c','d'])
telco_clean_df

charges_corrected = telco_clean_df[telco_clean_df.total_charges != 0]
charges_corrected['total_charges'].describe()
# Out:
# count    7032.000000
# mean     2283.147248
# std      2264.703327
# min        18.800000
# 25%       397.800000
# 50%      1394.575000
# 75%      3791.250000
# max      8550.000000
# Name: total_charges, dtype: float64

# %%
readable_telco = pd.get_dummies(telco_clean_df[['charge_rank', 'internet_service_type', 'gender', 'senior_citizen', 'partner', 
                                                'contract_type', 'dependents', 'phone_service','multiple_lines',
                                               'online_security', 'online_backup','device_protection','streaming_tv', 
                                                'paperless_billing','churn', 'contract_type','internet_service_type',
                                               'payment_type']],drop_first = [True, True])
readable_telco
# Out:
#       senior_citizen  charge_rank_b  charge_rank_c  charge_rank_d  \
# 0                  0              1              0              0
# 1                  0              1              0              0
# 2                  0              0              0              0
# 3                  1              1              0              0
# 4                  1              0              0              0
# ...              ...            ...            ...            ...
# 7038               0              0              0              0
# 7039               0              0              0              0
# 7040               0              1              0              0
# 7041               0              0              0              1
# 7042               1              0              1              0
#
#       internet_service_type_Fiber optic  internet_service_type_None  \
# 0                                     0                           0
# 1                                     0                           0
# 2                                     1                           0
# 3                                     1                           0
# 4                                     1                           0
# ...                                 ...                         ...
# 7038                                  1                           0
# 7039                                  0                           0
# 7040                                  0                           0
# 7041                                  1                           0
# 7042                                  1                           0
#
#       gender_Male  partner_Yes  contract_type_One year  \
# 0               0            1                       1
# 1               1            0                       0
# 2               1            0                       0
# 3               1            1                       0
# 4               0            1                       0
# ...           ...          ...                     ...
# 7038            0            0                       0
# 7039            1            0                       0
# 7040            0            1                       1
# 7041            1            1                       0
# 7042            1            0                       0
#
#       contract_type_Two year  ...  streaming_tv_Yes  paperless_billing_Yes  \
# 0                          0  ...                 1                      1
# 1                          0  ...                 0                      0
# 2                          0  ...                 0                      1
# 3                          0  ...                 1                      1
# 4                          0  ...                 1                      1
# ...                      ...  ...               ...                    ...
# 7038                       0  ...                 0                      1
# 7039                       0  ...                 0                      0
# 7040                       0  ...                 0                      0
# 7041                       1  ...                 0                      0
# 7042                       0  ...                 1                      1
#
#       churn_Yes  contract_type_One year  contract_type_Two year  \
# 0             0                       1                       0
# 1             0                       0                       0
# 2             1                       0                       0
# 3             1                       0                       0
# 4             1                       0                       0
# ...         ...                     ...                     ...
# 7038          1                       0                       0
# 7039          1                       0                       0
# 7040          0                       1                       0
# 7041          0                       0                       1
# 7042          1                       0                       0
#
#       internet_service_type_Fiber optic  internet_service_type_None  \
# 0                                     0                           0
# 1                                     0                           0
# 2                                     1                           0
# 3                                     1                           0
# 4                                     1                           0
# ...                                 ...                         ...
# 7038                                  1                           0
# 7039                                  0                           0
# 7040                                  0                           0
# 7041                                  1                           0
# 7042                                  1                           0
#
#       payment_type_Credit card (automatic)  payment_type_Electronic check  \
# 0                                        0                              0
# 1                                        0                              0
# 2                                        0                              1
# 3                                        0                              1
# 4                                        0                              0
# ...                                    ...                            ...
# 7038                                     0                              1
# 7039                                     0                              0
# 7040                                     0                              0
# 7041                                     0                              0
# 7042                                     0                              1
#
#       payment_type_Mailed check
# 0                             1
# 1                             1
# 2                             0
# 3                             0
# 4                             1
# ...                         ...
# 7038                          0
# 7039                          1
# 7040                          0
# 7041                          0
# 7042                          0
#
# [7043 rows x 31 columns]

# %%
telco_train, telco_val, telco_test = prepare.train_val_test(readable_telco, 'churn_Yes')

# %%
telco_train
# Out:
#       senior_citizen  charge_rank_b  charge_rank_c  charge_rank_d  \
# 5575               0              0              1              0
# 2312               0              0              1              0
# 6912               0              0              0              1
# 2247               0              1              0              0
# 805                1              0              0              0
# ...              ...            ...            ...            ...
# 4235               0              0              0              1
# 1493               0              1              0              0
# 6303               0              1              0              0
# 2707               0              0              0              1
# 5648               0              1              0              0
#
#       internet_service_type_Fiber optic  internet_service_type_None  \
# 5575                                  1                           0
# 2312                                  1                           0
# 6912                                  1                           0
# 2247                                  1                           0
# 805                                   1                           0
# ...                                 ...                         ...
# 4235                                  0                           0
# 1493                                  0                           1
# 6303                                  0                           0
# 2707                                  0                           0
# 5648                                  0                           1
#
#       gender_Male  partner_Yes  contract_type_One year  \
# 5575            1            1                       1
# 2312            0            1                       1
# 6912            1            0                       0
# 2247            1            0                       0
# 805             0            0                       0
# ...           ...          ...                     ...
# 4235            0            1                       0
# 1493            1            1                       0
# 6303            0            1                       0
# 2707            1            1                       0
# 5648            1            1                       1
#
#       contract_type_Two year  ...  streaming_tv_Yes  paperless_billing_Yes  \
# 5575                       0  ...                 1                      0
# 2312                       0  ...                 0                      1
# 6912                       1  ...                 1                      1
# 2247                       0  ...                 1                      1
# 805                        0  ...                 1                      0
# ...                      ...  ...               ...                    ...
# 4235                       1  ...                 0                      1
# 1493                       1  ...                 0                      0
# 6303                       0  ...                 0                      1
# 2707                       1  ...                 1                      1
# 5648                       0  ...                 0                      0
#
#       churn_Yes  contract_type_One year  contract_type_Two year  \
# 5575          0                       1                       0
# 2312          1                       1                       0
# 6912          1                       0                       1
# 2247          0                       0                       0
# 805           1                       0                       0
# ...         ...                     ...                     ...
# 4235          0                       0                       1
# 1493          0                       0                       1
# 6303          0                       0                       0
# 2707          0                       0                       1
# 5648          0                       1                       0
#
#       internet_service_type_Fiber optic  internet_service_type_None  \
# 5575                                  1                           0
# 2312                                  1                           0
# 6912                                  1                           0
# 2247                                  1                           0
# 805                                   1                           0
# ...                                 ...                         ...
# 4235                                  0                           0
# 1493                                  0                           1
# 6303                                  0                           0
# 2707                                  0                           0
# 5648                                  0                           1
#
#       payment_type_Credit card (automatic)  payment_type_Electronic check  \
# 5575                                     0                              0
# 2312                                     0                              1
# 6912                                     1                              0
# 2247                                     0                              1
# 805                                      0                              1
# ...                                    ...                            ...
# 4235                                     1                              0
# 1493                                     0                              0
# 6303                                     0                              1
# 2707                                     1                              0
# 5648                                     0                              0
#
#       payment_type_Mailed check
# 5575                          0
# 2312                          0
# 6912                          0
# 2247                          0
# 805                           0
# ...                         ...
# 4235                          0
# 1493                          1
# 6303                          0
# 2707                          0
# 5648                          0
#
# [4930 rows x 31 columns]

# %%
x_train = telco_train.drop(columns = ['churn_Yes'])
y_train = telco_train['churn_Yes']
x_val = telco_val.drop(columns = ['churn_Yes'])
y_val = telco_val['churn_Yes']
x_test = telco_test.drop(columns = ['churn_Yes'])
y_test = telco_test['churn_Yes']

# %% [markdown]
# ## Random Forest

# %%
seed = 99

rf_telco = RandomForestClassifier(max_depth = 10, random_state = seed, min_samples_leaf = 1, max_samples = 0.5)
bsl = 1-(y_train.sum()/len(y_train))
bsl
# Out:
# 0.734685598377282

# %%
for1 = rf_telco.fit(x_train, y_train)

# %%
importance_df = pd.DataFrame({'feature': x_train.columns.tolist(), 
              'importance': rf_telco.feature_importances_})

# %%
importance_df.sort_values('importance', ascending = False)
# Out:
#                                   feature  importance
# 4       internet_service_type_Fiber optic    0.070928
# 24                 contract_type_Two year    0.060156
# 9                  contract_type_Two year    0.059824
# 25      internet_service_type_Fiber optic    0.059511
# 15                    online_security_Yes    0.059108
# 28          payment_type_Electronic check    0.058291
# 3                           charge_rank_d    0.052249
# 23                 contract_type_One year    0.047549
# 17                      online_backup_Yes    0.040140
# 6                             gender_Male    0.039681
# 8                  contract_type_One year    0.039221
# 22                  paperless_billing_Yes    0.039035
# 2                           charge_rank_c    0.035911
# 7                             partner_Yes    0.035504
# 21                       streaming_tv_Yes    0.032595
# 0                          senior_citizen    0.032306
# 10                         dependents_Yes    0.032064
# 1                           charge_rank_b    0.031881
# 19                  device_protection_Yes    0.030608
# 13                     multiple_lines_Yes    0.030284
# 27   payment_type_Credit card (automatic)    0.024149
# 29              payment_type_Mailed check    0.016527
# 5              internet_service_type_None    0.014774
# 14    online_security_No internet service    0.011405
# 16      online_backup_No internet service    0.009514
# 26             internet_service_type_None    0.008332
# 12        multiple_lines_No phone service    0.008145
# 11                      phone_service_Yes    0.007671
# 20       streaming_tv_No internet service    0.007659
# 18  device_protection_No internet service    0.004980

# %%
print(rf_telco.score(x_train, y_train),rf_telco.score(x_val, y_val))
# Out:
# 0.8298174442190669 0.8058712121212122

# %%
train_preds = rf_telco.predict(x_train)

# %%
pd.DataFrame(classification_report(y_train, train_preds, output_dict = True))
# Out:
#                      0            1  accuracy    macro avg  weighted avg
# precision     0.857070     0.727009  0.829817     0.792039      0.822563
# recall        0.922142     0.574159  0.829817     0.748151      0.829817
# f1-score      0.888416     0.641606  0.829817     0.765011      0.822934
# support    3622.000000  1308.000000  0.829817  4930.000000   4930.000000

# %%
metrics = []


def depth_n_leaf():
    msl = 1
    i = 3
    while msl <= 10:
        rf = RandomForestClassifier(max_depth = i,
                                    random_state = seed, min_samples_leaf = msl, max_samples = 0.5)
        rf.fit(x_train, y_train)
        train_acc = rf.score(x_train, y_train)
        val_acc = rf.score(x_val, y_val)
        output = {'max_depth': i, 'min_samples_leaf': msl, 'train_accuracy': train_acc, 
                  'validate_accuracy': val_acc}
        metrics.append(output)
        i = i +1
        if i == 11:
            msl = msl + 1
            i = 3


        
depth_n_leaf() 

metrics = pd.DataFrame(metrics)
metrics['difference'] = (metrics['train_accuracy'] - metrics['validate_accuracy'])    
metrics
# Out:
#     max_depth  min_samples_leaf  train_accuracy  validate_accuracy  difference
# 0           3                 1        0.759229           0.765152   -0.005922
# 1           4                 1        0.784381           0.788826   -0.004444
# 2           5                 1        0.790872           0.800189   -0.009317
# 3           6                 1        0.798377           0.803030   -0.004653
# 4           7                 1        0.804868           0.801136    0.003732
# 5           8                 1        0.808316           0.805871    0.002445
# 6           9                 1        0.819878           0.803977    0.015901
# 7          10                 1        0.829817           0.805871    0.023946
# 8           3                 2        0.759229           0.765152   -0.005922
# 9           4                 2        0.784381           0.788826   -0.004444
# 10          5                 2        0.790872           0.800189   -0.009317
# 11          6                 2        0.798174           0.801136   -0.002962
# 12          7                 2        0.801826           0.806818   -0.004993
# 13          8                 2        0.808925           0.803977    0.004948
# 14          9                 2        0.815213           0.804924    0.010289
# 15         10                 2        0.820081           0.804924    0.015157
# 16          3                 3        0.759229           0.765152   -0.005922
# 17          4                 3        0.784381           0.788826   -0.004444
# 18          5                 3        0.791481           0.800189   -0.008709
# 19          6                 3        0.797972           0.802083   -0.004112
# 20          7                 3        0.803245           0.803030    0.000215
# 21          8                 3        0.808316           0.806818    0.001498
# 22          9                 3        0.813590           0.811553    0.002037
# 23         10                 3        0.816836           0.806818    0.010018
# 24          3                 4        0.759229           0.765152   -0.005922
# 25          4                 4        0.784381           0.788826   -0.004444
# 26          5                 4        0.791075           0.799242   -0.008167
# 27          6                 4        0.796957           0.801136   -0.004179
# 28          7                 4        0.803448           0.803030    0.000418
# 29          8                 4        0.806085           0.805871    0.000214
# 30          9                 4        0.810953           0.808712    0.002241
# 31         10                 4        0.815619           0.809659    0.005960
# 32          3                 5        0.759229           0.765152   -0.005922
# 33          4                 5        0.784381           0.788826   -0.004444
# 34          5                 5        0.791278           0.800189   -0.008912
# 35          6                 5        0.797566           0.802083   -0.004517
# 36          7                 5        0.803651           0.803030    0.000621
# 37          8                 5        0.805882           0.799242    0.006640
# 38          9                 5        0.811562           0.808712    0.002850
# 39         10                 5        0.814604           0.806818    0.007786
# 40          3                 6        0.759229           0.765152   -0.005922
# 41          4                 6        0.784381           0.788826   -0.004444
# 42          5                 6        0.793103           0.801136   -0.008033
# 43          6                 6        0.797566           0.801136   -0.003570
# 44          7                 6        0.802434           0.805871   -0.003437
# 45          8                 6        0.806491           0.803977    0.002514
# 46          9                 6        0.809128           0.806818    0.002310
# 47         10                 6        0.811765           0.807765    0.004000
# 48          3                 7        0.759229           0.765152   -0.005922
# 49          4                 7        0.784381           0.788826   -0.004444
# 50          5                 7        0.792901           0.803030   -0.010130
# 51          6                 7        0.795943           0.801136   -0.005193
# 52          7                 7        0.800203           0.801136   -0.000934
# 53          8                 7        0.804665           0.807765   -0.003100
# 54          9                 7        0.808519           0.804924    0.003595
# 55         10                 7        0.811359           0.803977    0.007382
# 56          3                 8        0.759229           0.765152   -0.005922
# 57          4                 8        0.784381           0.788826   -0.004444
# 58          5                 8        0.794523           0.803977   -0.009454
# 59          6                 8        0.798174           0.803030   -0.004856
# 60          7                 8        0.801217           0.804924   -0.003707
# 61          8                 8        0.804462           0.808712   -0.004250
# 62          9                 8        0.806491           0.808712   -0.002221
# 63         10                 8        0.807302           0.806818    0.000484
# 64          3                 9        0.759229           0.765152   -0.005922
# 65          4                 9        0.784381           0.788826   -0.004444
# 66          5                 9        0.792495           0.802083   -0.009588
# 67          6                 9        0.796552           0.803030   -0.006479
# 68          7                 9        0.800406           0.804924   -0.004519
# 69          8                 9        0.803043           0.805871   -0.002829
# 70          9                 9        0.806897           0.804924    0.001972
# 71         10                 9        0.807708           0.809659   -0.001951
# 72          3                10        0.759229           0.765152   -0.005922
# 73          4                10        0.784584           0.788826   -0.004242
# 74          5                10        0.791075           0.799242   -0.008167
# 75          6                10        0.795132           0.803030   -0.007898
# 76          7                10        0.799391           0.803977   -0.004586
# 77          8                10        0.803854           0.806818   -0.002964
# 78          9                10        0.804462           0.803977    0.000485
# 79         10                10        0.806694           0.802083    0.004610

# %% [markdown]
# ## Decision Tree

# %%
clf = DecisionTreeClassifier(max_depth = 3, random_state = seed)

# %%
clf.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=99)

# %%
val_preds = clf.predict(x_val)

# %%
print(classification_report(y_val, val_preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.95      0.88       776
#            1       0.76      0.43      0.55       280
#
#     accuracy                           0.81      1056
#    macro avg       0.79      0.69      0.72      1056
# weighted avg       0.80      0.81      0.79      1056

# %%
clf.score(x_train, y_train)
# Out:
# 0.7862068965517242

# %%
big_clf = DecisionTreeClassifier(max_depth = 6, random_state = 99)

# %%
big_clf.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=6, random_state=99)

# %%
big_clf.score(x_train, y_train)
# Out:
# 0.8032454361054767

# %%
big_clf.score(x_val, y_val)
# Out:
# 0.8058712121212122

# %%
metrics = []

for i in range (1, 25):
    tree = DecisionTreeClassifier(max_depth = i, random_state = 99)
    tree = tree.fit(x_train, y_train)
    in_sample_accuracy = tree.score(x_train, y_train)
    out_of_sample_accuracy = tree.score(x_val, y_val)
    output = {'max_dept': i, 'train_accuracy': in_sample_accuracy, 'validate_accuracy': out_of_sample_accuracy}
    
    metrics.append(output)
    
df= pd.DataFrame(metrics)
df['difference'] = df.train_accuracy - df.validate_accuracy
df
# Out:
#     max_dept  train_accuracy  validate_accuracy  difference
# 0          1        0.734686           0.734848   -0.000163
# 1          2        0.770791           0.771780   -0.000989
# 2          3        0.786207           0.812500   -0.026293
# 3          4        0.789249           0.803977   -0.014728
# 4          5        0.794118           0.794508   -0.000390
# 5          6        0.803245           0.805871   -0.002626
# 6          7        0.807708           0.789773    0.017935
# 7          8        0.822515           0.787879    0.034636
# 8          9        0.835294           0.783144    0.052150
# 9         10        0.853955           0.771780    0.082175
# 10        11        0.869777           0.775568    0.094209
# 11        12        0.886613           0.777462    0.109150
# 12        13        0.901420           0.766098    0.135321
# 13        14        0.909939           0.758523    0.151416
# 14        15        0.918458           0.752841    0.165618
# 15        16        0.923529           0.750947    0.172582
# 16        17        0.926166           0.747159    0.179007
# 17        18        0.926978           0.747159    0.179819
# 18        19        0.927789           0.750947    0.176842
# 19        20        0.927789           0.746212    0.181577
# 20        21        0.927789           0.746212    0.181577
# 21        22        0.927789           0.746212    0.181577
# 22        23        0.927789           0.746212    0.181577
# 23        24        0.927789           0.746212    0.181577

# %% [markdown]
# ## KNN

# %%
knn = KNeighborsClassifier(n_neighbors = 5)
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
knn.score(x_train,y_train)
# Out:
# 0.8298174442190669

# %%
train_preds = knn.predict(x_train)
print(classification_report(y_train, train_preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.91      0.89      3622
#            1       0.70      0.62      0.66      1308
#
#     accuracy                           0.83      4930
#    macro avg       0.79      0.76      0.77      4930
# weighted avg       0.82      0.83      0.83      4930

# %%
num_neighbors = []
train_acc = []
val_acc = []

for i in range (1,21):
    knn = KNeighborsClassifier(n_neighbors = i)
    knn.fit(x_train, y_train)
    num_neighbors.append(i)
    train_acc.append(knn.score(x_train, y_train))
    val_acc.append(knn.score(x_val, y_val))
    
df_knn = pd.DataFrame({'neighbors': num_neighbors,
             'train_acc': train_acc,
             'val_acc': val_acc})

df_knn['difference'] = (df_knn['train_acc'] - df_knn['val_acc'])    
df_knn
# Out:
#     neighbors  train_acc   val_acc  difference
# 0           1   0.901623  0.717803    0.183820
# 1           2   0.843002  0.761364    0.081638
# 2           3   0.850913  0.768939    0.081973
# 3           4   0.833266  0.773674    0.059591
# 4           5   0.829817  0.781250    0.048567
# 5           6   0.824949  0.781250    0.043699
# 6           7   0.822515  0.770833    0.051682
# 7           8   0.820284  0.782197    0.038087
# 8           9   0.822718  0.776515    0.046203
# 9          10   0.814604  0.785985    0.028620
# 10         11   0.819878  0.778409    0.041469
# 11         12   0.815822  0.781250    0.034572
# 12         13   0.815822  0.788826    0.026996
# 13         14   0.814402  0.789773    0.024629
# 14         15   0.813793  0.792614    0.021179
# 15         16   0.813793  0.794508    0.019286
# 16         17   0.813387  0.792614    0.020774
# 17         18   0.811968  0.789773    0.022195
# 18         19   0.810953  0.790720    0.020234
# 19         20   0.808925  0.787879    0.021046
