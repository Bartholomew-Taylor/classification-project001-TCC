# %%
from sklearn.metrics import precision_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score
from sklearn.metrics import classification_report
import pandas as pd
from scipy import stats
from pydataset import data
import numpy as np
import env
import matplotlib.pyplot as plt
import os
import prepare
import acquire
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import classification_report, confusion_matrix

# %%
telco_df = acquire.get_telco_data()
telco_df.T
# Out:
#                                            0                    1     \
# Unnamed: 0                                    0                    1
# customer_id                          0002-ORFBO           0003-MKNFE
# payment_type_id                               2                    2
# internet_service_type_id                      1                    1
# contract_type_id                              2                    1
# gender                                   Female                 Male
# senior_citizen                                0                    0
# partner                                     Yes                   No
# dependents                                  Yes                   No
# tenure                                        9                    9
# phone_service                               Yes                  Yes
# multiple_lines                               No                  Yes
# online_security                              No                   No
# ...

# %%
telco_clean_df = prepare.clean_telco(telco_df)
telco_clean_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 telco_clean_df = prepare.clean_telco(telco_df)
#       2 telco_clean_df.head()
#
# File ~/codeup-data-science/classification-project001-TCC/prepare.py:23, in clean_telco(df)
#      12 '''
#      13 this function cleans up the telco db
#      14 '''
#      16 to_drop = ['customer_id','internet_service_type_id', 'internet_service_type_id.1',
#      17            'contract_type_id', 'payment_type_id', 'internet_service_type_id',
#      18            'senior_citzen.1', 'payment_id.1', 'gender.1', 'contract_typle_id.1',
#    (...)
#      21            'multiple.lines.1', 'online_security.1','online_backup.1','device_protection.1',
#      22            'tech_support.1', 'streaming_tv.1','streaming_movies.1']
# ---> 23 df.drop(columns = to_drop, inplace = True)
# ...

# %%
telco_clean_df.T

# %%
readable_telco = pd.get_dummies(telco_clean_df[['gender', 'partner', 'dependents', 'phone_service', 'multiple_lines', 'online_security',
                            'online_backup','device_protection', 'tech_support', 'streaming_tv', 'streaming_movies', 
                            'paperless_billing', 'churn', 'contract_type', 'internet_service_type', 
                             'payment_type']],drop_first = [True, True])

# %%
readable_telco.head()

# %%
readable_telco[readable_telco.partner_Yes == True].sum()
