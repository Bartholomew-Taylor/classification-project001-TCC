# %%
from sklearn.metrics import precision_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score
from sklearn.metrics import classification_report
import pandas as pd
from scipy import stats
from pydataset import data
import numpy as np
import env
import matplotlib.pyplot as plt
import os
import prepare
import acquire
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import classification_report, confusion_matrix

# %%
telco_df = acquire.get_telco_data()
telco_df.head()
# Out:
#    Unnamed: 0 customer_id  payment_type_id  internet_service_type_id  \
# 0           0  0002-ORFBO                2                         1
# 1           1  0003-MKNFE                2                         1
# 2           2  0004-TLHLJ                1                         2
# 3           3  0011-IGKFF                1                         2
# 4           4  0013-EXCHZ                2                         2
#
#    contract_type_id  gender  senior_citizen partner dependents  tenure  ...  \
# 0                 2  Female               0     Yes        Yes       9  ...
# 1                 1    Male               0      No         No       9  ...
# 2                 1    Male               0      No         No       4  ...
# 3                 1    Male               1     Yes         No      13  ...
# 4                 1  Female               1     Yes         No       3  ...
#
#            signup_date phone_service.1 multiple_lines.1  \
# ...

# %%
def clean_telco(df):
    '''
    this function cleans up the telco db
    '''
    
    to_drop = ['customer_id','internet_service_type_id', 'internet_service_type_id.1', 'contract_type_id', 'payment_type_id', 'internet_service_type_id']
    df.drop(columns = to_drop, inplace = True)
    return df

telco_clean_df = clean_telco(telco_df)
telco_clean_df.head()
# Out:
#    Unnamed: 0  gender  senior_citizen partner dependents  tenure  \
# 0           0  Female               0     Yes        Yes       9
# 1           1    Male               0      No         No       9
# 2           2    Male               0      No         No       4
# 3           3    Male               1     Yes         No      13
# 4           4  Female               1     Yes         No       3
#
#   phone_service multiple_lines online_security online_backup  ...  \
# 0           Yes             No              No           Yes  ...
# 1           Yes            Yes              No            No  ...
# 2           Yes             No              No            No  ...
# 3           Yes             No              No           Yes  ...
# 4           Yes             No              No            No  ...
#
#   total_charges.1          signup_date phone_service.1 multiple_lines.1  \
# 0           593.3  2021-04-21 18:07:34             Yes               No
# ...

# %%
telco_clean_df = telco_clean_df.drop(telco_clean_df.columns[0], axis = 1)

# %%
telco_clean_df.head()
# Out:
#    gender  senior_citizen partner dependents  tenure phone_service  \
# 0  Female               0     Yes        Yes       9           Yes
# 1    Male               0      No         No       9           Yes
# 2    Male               0      No         No       4           Yes
# 3    Male               1     Yes         No      13           Yes
# 4  Female               1     Yes         No       3           Yes
#
#   multiple_lines online_security online_backup device_protection  ...  \
# 0             No              No           Yes                No  ...
# 1            Yes              No            No                No  ...
# 2             No              No            No               Yes  ...
# 3             No              No           Yes               Yes  ...
# 4             No              No            No                No  ...
#
#            signup_date phone_service.1 multiple_lines.1  \
# 0  2021-04-21 18:07:34             Yes               No
# ...
